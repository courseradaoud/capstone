# %% [markdown]
# Aim: This project is aimed to help tourists who come to Berlin to find the Museums near to.
#
# In Berlin there ara many museums that you can visit and each one has special features and each Museum give you new experience. When a tourists come to Berlin he/she may not be able to decide which Museum he/she should visit first, especially if the time is limited.
#
#
#
# 1- the geojson data for Berlin is required.
# 2- Then, analyzing the data using the Foursquare API.
# 3- Use clustering to identify each area and its category.
# Data Source we are going to use is from Foursquare. Foursquare is a technology company that uses location intelligence to build meaningful consumer experiences and business solutions. So We are going to build a project with the help of Foursquare location data, Foursquare API provides great amount of quality data’s about locations.(cafe, restaurant etc) Using this data will allow tourists to easily decide where to go when they are in a specific city. Using techniques such as K-means clustering, I was able to get results about common venues in city. This information can be really helpful to tourists since they can focus on what they are trying to experience most during their Travel .(Food, culture, sport etc) These techniques also provides the visualization of clustering of city. k-means clustering is a method of vector quantization, originally from signal processing, that is popular for cluster analysis in data mining. k-means clustering aims to partition n observations into k clusters in which each observation belongs to the cluster with the nearest mean, serving as a prototype of the cluster. This results in a partitioning of the data space into Voronoi cells

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# !pip install folium
import requests
from bs4 import BeautifulSoup
import lxml
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
import json
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframev
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
print("All libraries installed and imported ! ")
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.17.0-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00   1.03 MB/s
# geopy-1.17.0-p 100% |################################| Time: 0:00:00   1.58 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00   3.16 MB/s
# branca-0.3.1-p 100% |################################| Time: 0:00:00  30.97 MB/s
# vincent-0.4.4- 100% |################################| Time: 0:00:00  31.61 MB/s
# folium-0.5.0-p 100% |################################| Time: 0:00:00  22.64 MB/s
# Requirement not upgraded as not directly required: folium in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages
# Requirement not upgraded as not directly required: branca in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: jinja2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: requests in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: six in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: MarkupSafe>=0.23 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from jinja2->folium)
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Requirement not upgraded as not directly required: idna<2.7,>=2.5 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Requirement not upgraded as not directly required: urllib3<1.23,>=1.21.1 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# All libraries installed and imported !

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# My credentails:
# CLIENT_ID: G0XJ2XFI1IPZMUR52JRVDEA31QO4DTXKTTIQ1DMOGM5EN0PU
# CLIENT_SECRET:ZPA4XLVKKH5APZSWDPD2SEW3FZ02GNMFTXY1KJG4KBNHRYAB

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&categoryId={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat, long, VERSION, cat, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=G0XJ2XFI1IPZMUR52JRVDEA31QO4DTXKTTIQ1DMOGM5EN0PU&client_secret=ZPA4XLVKKH5APZSWDPD2SEW3FZ02GNMFTXY1KJG4KBNHRYAB&ll=52.520778,13.397558&v=20180604&categoryId=4bf58dd8d48988d181941735&radius=10000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c012302db04f56ae878e7bb'},
#  'response': {'confident': False,
#   'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'primary': True,
#       'shortName': 'History Museum'}],
#     'hasPerk': False,
#     'id': '4ae44d24f964a520eb9921e3',
#     'location': {'address': 'Am Kupfergraben 5',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 79,
#      'formattedAddress': ['Am Kupfergraben 5', '10117 Berlin', 'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.520843,
#        'lng': 13.396395}],
#      'lat': 52.520843,
#      'lng': 13.396395,
#      'neighborhood': 'Museumsinsel',
#      'postalCode': '10117',
#      'state': 'Berlin'},
#     'name': 'Pergamonmuseum',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d18f941735',
#       'name': 'Art Museum',
#       'pluralName': 'Art Museums',
#       'primary': True,
#       'shortName': 'Art Museum'}],
#     'hasPerk': False,
#     'id': '4adcda81f964a5205d4821e3',
#     'location': {'address': 'Am Kupfergraben 5',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 58,
#      'formattedAddress': ['Am Kupfergraben 5', '10117 Berlin', 'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.520708902848284,
#        'lng': 13.396697345529542}],
#      'lat': 52.520708902848284,
#      'lng': 13.396697345529542,
#      'postalCode': '10117',
#      'state': 'Berlin'},
#     'name': 'Museum für Islamische Kunst',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'primary': True,
#       'shortName': 'History Museum'}],
#     'hasPerk': False,
#     'id': '4adcda83f964a520b24821e3',
#     'location': {'address': 'Bodestr. 1-3',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'crossStreet': 'Museumsinsel',
#      'distance': 71,
#      'formattedAddress': ['Bodestr. 1-3 (Museumsinsel)',
#       '10178 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.5201576091737,
#        'lng': 13.39783787727356}],
#      'lat': 52.5201576091737,
#      'lng': 13.39783787727356,
#      'neighborhood': 'Museumsinsel',
#      'postalCode': '10178',
#      'state': 'Berlin'},
#     'name': 'Neues Museum',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d18f941735',
#       'name': 'Art Museum',
#       'pluralName': 'Art Museums',
#       'primary': True,
#       'shortName': 'Art Museum'}],
#     'hasPerk': False,
#     'id': '4adcda7cf964a520594721e3',
#     'location': {'address': 'Bodestr. 1-3',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 75,
#      'formattedAddress': ['Bodestr. 1-3', '10178 Berlin', 'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.520796016677,
#        'lng': 13.398673088379343}],
#      'lat': 52.520796016677,
#      'lng': 13.398673088379343,
#      'neighborhood': 'Museumsinsel',
#      'postalCode': '10178',
#      'state': 'Berlin'},
#     'name': 'Alte Nationalgalerie',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_science_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d191941735',
#       'name': 'Science Museum',
#       'pluralName': 'Science Museums',
#       'primary': True,
#       'shortName': 'Science Museum'}],
#     'hasPerk': False,
#     'id': '4adcda81f964a520594821e3',
#     'location': {'address': 'Invalidenstr. 43',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 1627,
#      'formattedAddress': ['Invalidenstr. 43', '10115 Berlin', 'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.53027102772721,
#        'lng': 13.379281262570908}],
#      'lat': 52.53027102772721,
#      'lng': 13.379281262570908,
#      'postalCode': '10115',
#      'state': 'Berlin'},
#     'name': 'Museum für Naturkunde',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'primary': True,
#       'shortName': 'History Museum'}],
#     'hasPerk': False,
#     'id': '4adcda83f964a520aa4821e3',
#     'location': {'address': 'Unter den Linden 2',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 335,
#      'formattedAddress': ['Unter den Linden 2', '10117 Berlin', 'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.5177881130353,
#        'lng': 13.39694770969441}],
#      'lat': 52.5177881130353,
#      'lng': 13.39694770969441,
#      'postalCode': '10117',
#      'state': 'Berlin'},
#     'name': 'Deutsches Historisches Museum',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'primary': True,
#       'shortName': 'History Museum'}],
#     'hasPerk': False,
#     'id': '4b39de5bf964a520585f25e3',
#     'location': {'address': 'Brunnenstr. 105',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 3059,
#      'formattedAddress': ['Brunnenstr. 105', '13355 Berlin', 'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.54774454143173,
#        'lng': 13.388863673656248}],
#      'lat': 52.54774454143173,
#      'lng': 13.388863673656248,
#      'postalCode': '13355',
#      'state': 'Berlin'},
#     'name': 'Berliner Unterwelten e.V.',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'primary': True,
#       'shortName': 'History Museum'}],
#     'hasPerk': False,
#     'id': '53245d85498ebfbd8bccba47',
#     'location': {'address': 'Bernauer Str. 111',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'crossStreet': 'Ackerstr.',
#      'distance': 1711,
#      'formattedAddress': ['Bernauer Str. 111 (Ackerstr.)',
#       '13355 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.53538550851109,
#        'lng': 13.389667868614197}],
#      'lat': 52.53538550851109,
#      'lng': 13.389667868614197,
#      'postalCode': '13355',
#      'state': 'Berlin'},
#     'name': 'Dokumentationszentrum | Documentation Center (Dokumentationszentrum)',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/touristinformation_',
#        'suffix': '.png'},
#       'id': '4f4530164b9074f6e4fb00ff',
#       'name': 'Tourist Information Center',
#       'pluralName': 'Tourist Information Centers',
#       'primary': True,
#       'shortName': 'Tourist Information'}],
#     'hasPerk': False,
#     'id': '4e8f16ebf5b910ae60bb90dc',
#     'location': {'address': 'Bernauer Str. 119',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'crossStreet': 'Gartenstr.',
#      'distance': 1598,
#      'formattedAddress': ['Bernauer Str. 119 (Gartenstr.)',
#       '13355 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.53376701989025,
#        'lng': 13.387484550476074}],
#      'lat': 52.53376701989025,
#      'lng': 13.387484550476074,
#      'neighborhood': 'Gesundbrunnen',
#      'postalCode': '13355',
#      'state': 'Berlin'},
#     'name': 'Besucherzentrum | Visitor Center (Besucherzentrum)',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d18f941735',
#       'name': 'Art Museum',
#       'pluralName': 'Art Museums',
#       'primary': True,
#       'shortName': 'Art Museum'}],
#     'hasPerk': False,
#     'id': '4adcda81f964a520784821e3',
#     'location': {'address': 'Alte Jakobstr. 124-128',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 1924,
#      'formattedAddress': ['Alte Jakobstr. 124-128',
#       '10969 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.50349443401274,
#        'lng': 13.398402651232848}],
#      'lat': 52.50349443401274,
#      'lng': 13.398402651232848,
#      'postalCode': '10969',
#      'state': 'Berlin'},
#     'name': 'Berlinische Galerie',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_science_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d191941735',
#       'name': 'Science Museum',
#       'pluralName': 'Science Museums',
#       'primary': True,
#       'shortName': 'Science Museum'}],
#     'hasPerk': False,
#     'id': '4b659b4bf964a52032f62ae3',
#     'location': {'address': 'Trebbiner Str. 9',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 2852,
#      'formattedAddress': ['Trebbiner Str. 9', '10963 Berlin', 'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.49845963432423,
#        'lng': 13.376881343063012}],
#      'lat': 52.49845963432423,
#      'lng': 13.376881343063012,
#      'postalCode': '10963',
#      'state': 'Berlin'},
#     'name': 'Deutsches Technikmuseum (Deutsches Technikmuseum Berlin)',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#        'suffix': '.png'},
#       'id': '52e81612bcbc57f1066b7a14',
#       'name': 'Palace',
#       'pluralName': 'Palaces',
#       'primary': True,
#       'shortName': 'Palace'}],
#     'hasPerk': False,
#     'id': '4adcda7cf964a520564721e3',
#     'location': {'address': 'Spandauer Damm 20',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 6901,
#      'formattedAddress': ['Spandauer Damm 20', '14059 Berlin', 'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.52089530162469,
#        'lng': 13.29566717147827}],
#      'lat': 52.52089530162469,
#      'lng': 13.29566717147827,
#      'neighborhood': 'Charlottenburg',
#      'postalCode': '14059',
#      'state': 'Berlin'},
#     'name': 'Schloss Charlottenburg',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'primary': True,
#       'shortName': 'History Museum'}],
#     'hasPerk': False,
#     'id': '4ae9c897f964a52062b621e3',
#     'location': {'address': 'Karl-Liebknecht-Str. 1',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 352,
#      'formattedAddress': ['Karl-Liebknecht-Str. 1',
#       '10178 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.51940384308041,
#        'lng': 13.40223855826597}],
#      'lat': 52.51940384308041,
#      'lng': 13.40223855826597,
#      'postalCode': '10178',
#      'state': 'Berlin'},
#     'name': 'DDR Museum',
#     'referralId': 'v-1543578371',
#     'venuePage': {'id': '48098990'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d18f941735',
#       'name': 'Art Museum',
#       'pluralName': 'Art Museums',
#       'primary': True,
#       'shortName': 'Art Museum'}],
#     'hasPerk': False,
#     'id': '4adcda83f964a520b04821e3',
#     'location': {'address': 'Niederkirchnerstr. 7',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 1865,
#      'formattedAddress': ['Niederkirchnerstr. 7',
#       '10963 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.506996303785236,
#        'lng': 13.381885753847431}],
#      'lat': 52.506996303785236,
#      'lng': 13.381885753847431,
#      'neighborhood': 'Kreuzberg',
#      'postalCode': '10963',
#      'state': 'Berlin'},
#     'name': 'Martin-Gropius-Bau',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'primary': True,
#       'shortName': 'History Museum'}],
#     'hasPerk': False,
#     'id': '4adcda81f964a520574821e3',
#     'location': {'address': 'Am Lustgarten 1',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 161,
#      'formattedAddress': ['Am Lustgarten 1', '10178 Berlin', 'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.51953741567019,
#        'lng': 13.398803472518921}],
#      'lat': 52.51953741567019,
#      'lng': 13.398803472518921,
#      'neighborhood': 'Museumsinsel',
#      'postalCode': '10178',
#      'state': 'Berlin'},
#     'name': 'Altes Museum',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d18f941735',
#       'name': 'Art Museum',
#       'pluralName': 'Art Museums',
#       'primary': True,
#       'shortName': 'Art Museum'}],
#     'hasPerk': False,
#     'id': '4adcda83f964a520ab4821e3',
#     'location': {'address': 'Invalidenstr. 50-51',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 1879,
#      'formattedAddress': ['Invalidenstr. 50-51',
#       '10557 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.52811924345585,
#        'lng': 13.37257554066581}],
#      'lat': 52.52811924345585,
#      'lng': 13.37257554066581,
#      'neighborhood': 'Hauptbahnhof',
#      'postalCode': '10557',
#      'state': 'Berlin'},
#     'name': 'Hamburger Bahnhof – Museum für Gegenwart',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'primary': True,
#       'shortName': 'History Museum'}],
#     'hasPerk': False,
#     'id': '4adcda83f964a520944821e3',
#     'location': {'address': 'Niederkirchnerstr. 8',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'crossStreet': 'Wilhelmstr.',
#      'distance': 1812,
#      'formattedAddress': ['Niederkirchnerstr. 8 (Wilhelmstr.)',
#       '10963 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.506883557050294,
#        'lng': 13.38360071182251}],
#      'lat': 52.506883557050294,
#      'lng': 13.38360071182251,
#      'postalCode': '10963',
#      'state': 'Berlin'},
#     'name': 'Topographie des Terrors',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d18f941735',
#       'name': 'Art Museum',
#       'pluralName': 'Art Museums',
#       'primary': True,
#       'shortName': 'Art Museum'}],
#     'hasPerk': False,
#     'id': '5228b7737e484ee899dce79b',
#     'location': {'address': 'Hardenbergstr. 22-24',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 4784,
#      'formattedAddress': ['Hardenbergstr. 22-24',
#       '10623 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.50678358537336,
#        'lng': 13.330788985134213}],
#      'lat': 52.50678358537336,
#      'lng': 13.330788985134213,
#      'postalCode': '10623',
#      'state': 'Berlin'},
#     'name': 'C/O Berlin',
#     'referralId': 'v-1543578371',
#     'venuePage': {'id': '124350650'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'primary': True,
#       'shortName': 'History Museum'}],
#     'hasPerk': False,
#     'id': '4adcda81f964a520484821e3',
#     'location': {'address': 'Ruschestr. 103',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'crossStreet': 'Haus 1',
#      'distance': 6122,
#      'formattedAddress': ['Ruschestr. 103 (Haus 1)',
#       '10365 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.514366619602,
#        'lng': 13.487327098846436}],
#      'lat': 52.514366619602,
#      'lng': 13.487327098846436,
#      'postalCode': '10365',
#      'state': 'Berlin'},
#     'name': 'Stasi-Museum',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#        'suffix': '.png'},
#       'id': '4deefb944765f83613cdba6e',
#       'name': 'Historic Site',
#       'pluralName': 'Historic Sites',
#       'primary': True,
#       'shortName': 'Historic Site'}],
#     'hasPerk': False,
#     'id': '4bd975242e6f0f4708960a08',
#     'location': {'address': 'Bernauer Str. 111',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'crossStreet': 'Ackerstr.',
#      'distance': 1649,
#      'formattedAddress': ['Bernauer Str. 111 (Ackerstr.)',
#       '13355 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.534896052519215,
#        'lng': 13.390139937400818}],
#      'lat': 52.534896052519215,
#      'lng': 13.390139937400818,
#      'neighborhood': 'Mitte',
#      'postalCode': '13355',
#      'state': 'Berlin'},
#     'name': 'Gedenkstätte Berliner Mauer',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'primary': True,
#       'shortName': 'History Museum'}],
#     'hasPerk': False,
#     'id': '4adcda81f964a520584821e3',
#     'location': {'address': 'Lindenstr. 9-14',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'crossStreet': 'Am Berlin Museum',
#      'distance': 2102,
#      'formattedAddress': ['Lindenstr. 9-14 (Am Berlin Museum)',
#       '10969 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.501946388929426,
#        'lng': 13.395241498947144}],
#      'lat': 52.501946388929426,
#      'lng': 13.395241498947144,
#      'postalCode': '10969',
#      'state': 'Berlin'},
#     'name': 'Jüdisches Museum (Jüdisches Museum Berlin)',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d18f941735',
#       'name': 'Art Museum',
#       'pluralName': 'Art Museums',
#       'primary': True,
#       'shortName': 'Art Museum'}],
#     'hasPerk': False,
#     'id': '4adcda83f964a520934821e3',
#     'location': {'address': 'Matthäikirchplatz 8',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 2478,
#      'formattedAddress': ['Matthäikirchplatz 8',
#       '10785 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.50896347323177,
#        'lng': 13.366553250421635}],
#      'lat': 52.50896347323177,
#      'lng': 13.366553250421635,
#      'postalCode': '10785',
#      'state': 'Berlin'},
#     'name': 'Gemäldegalerie',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'primary': True,
#       'shortName': 'History Museum'}],
#     'hasPerk': False,
#     'id': '55fa78a1498ea1907ff6be9f',
#     'location': {'address': 'Leipziger Platz 9',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 1831,
#      'formattedAddress': ['Leipziger Platz 9', '10117 Berlin', 'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.50889483693721,
#        'lng': 13.37885856628418}],
#      'lat': 52.50889483693721,
#      'lng': 13.37885856628418,
#      'postalCode': '10117',
#      'state': 'Berlin'},
#     'name': 'Deutsches Spionagemuseum',
#     'referralId': 'v-1543578371',
#     'venuePage': {'id': '226317899'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_planetarium_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d192941735',
#       'name': 'Planetarium',
#       'pluralName': 'Planetariums',
#       'primary': True,
#       'shortName': 'Planetarium'}],
#     'hasPerk': False,
#     'id': '4adcda7df964a520914721e3',
#     'location': {'address': 'Prenzlauer Allee 80',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 3215,
#      'formattedAddress': ['Prenzlauer Allee 80',
#       '10405 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.5431275302158,
#        'lng': 13.42764682031945}],
#      'lat': 52.5431275302158,
#      'lng': 13.42764682031945,
#      'postalCode': '10405',
#      'state': 'Berlin'},
#     'name': 'Zeiss-Großplanetarium',
#     'referralId': 'v-1543578371',
#     'venuePage': {'id': '72906030'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d181941735',
#       'name': 'Museum',
#       'pluralName': 'Museums',
#       'primary': True,
#       'shortName': 'Museum'}],
#     'hasPerk': False,
#     'id': '4b88e416f964a5203d1232e3',
#     'location': {'address': 'Unter den Linden 74',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'crossStreet': 'Wilhelmstr.',
#      'distance': 1181,
#      'formattedAddress': ['Unter den Linden 74 (Wilhelmstr.)',
#       '10117 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.51676928739977,
#        'lng': 13.381401300430298}],
#      'lat': 52.51676928739977,
#      'lng': 13.381401300430298,
#      'postalCode': '10117',
#      'state': 'Berlin'},
#     'name': 'Madame Tussauds',
#     'referralId': 'v-1543578371',
#     'venuePage': {'id': '517819679'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d181941735',
#       'name': 'Museum',
#       'pluralName': 'Museums',
#       'primary': True,
#       'shortName': 'Museum'}],
#     'hasPerk': False,
#     'id': '4adcda83f964a520af4821e3',
#     'location': {'address': 'Wiebestr. 36',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'crossStreet': 'Sickingenstr.',
#      'distance': 5442,
#      'formattedAddress': ['Wiebestr. 36 (Sickingenstr.)',
#       '10553 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.53026879229302,
#        'lng': 13.318734169006348}],
#      'lat': 52.53026879229302,
#      'lng': 13.318734169006348,
#      'postalCode': '10553',
#      'state': 'Berlin'},
#     'name': 'Classic Remise Berlin',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d18f941735',
#       'name': 'Art Museum',
#       'pluralName': 'Art Museums',
#       'primary': True,
#       'shortName': 'Art Museum'}],
#     'hasPerk': False,
#     'id': '4adcda83f964a520b44821e3',
#     'location': {'address': 'Jebensstr. 2',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 4639,
#      'formattedAddress': ['Jebensstr. 2', '10623 Berlin', 'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.50803664535491,
#        'lng': 13.33235194083391}],
#      'lat': 52.50803664535491,
#      'lng': 13.33235194083391,
#      'postalCode': '10623',
#      'state': 'Berlin'},
#     'name': 'Museum für Fotografie',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_science_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d191941735',
#       'name': 'Science Museum',
#       'pluralName': 'Science Museums',
#       'primary': True,
#       'shortName': 'Science Museum'}],
#     'hasPerk': False,
#     'id': '4c2d9e87260bc92801531ad3',
#     'location': {'address': 'Karl-Marx-Allee 93a',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 3025,
#      'formattedAddress': ['Karl-Marx-Allee 93a',
#       '10243 Berlin',
#       'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.51748970846354,
#        'lng': 13.441899511634173}],
#      'lat': 52.51748970846354,
#      'lng': 13.441899511634173,
#      'postalCode': '10243',
#      'state': 'Berlin'},
#     'name': 'Computerspielemuseum',
#     'referralId': 'v-1543578371',
#     'venuePage': {'id': '356231983'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#        'suffix': '.png'},
#       'id': '4deefb944765f83613cdba6e',
#       'name': 'Historic Site',
#       'pluralName': 'Historic Sites',
#       'primary': True,
#       'shortName': 'Historic Site'}],
#     'hasPerk': False,
#     'id': '4cc9350ed147a09328aee5ae',
#     'location': {'address': 'Reichstagufer 17',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 704,
#      'formattedAddress': ['Reichstagufer 17', '10117 Berlin', 'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.52085424559891,
#        'lng': 13.387162011117056}],
#      'lat': 52.52085424559891,
#      'lng': 13.387162011117056,
#      'postalCode': '10117',
#      'state': 'Berlin'},
#     'name': 'Tränenpalast',
#     'referralId': 'v-1543578371'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_science_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d191941735',
#       'name': 'Science Museum',
#       'pluralName': 'Science Museums',
#       'primary': True,
#       'shortName': 'Science Museum'}],
#     'hasPerk': False,
#     'id': '4b991062f964a520f35e35e3',
#     'location': {'address': 'Möckernstr. 26',
#      'cc': 'DE',
#      'city': 'Berlin',
#      'country': 'Deutschland',
#      'distance': 2834,
#      'formattedAddress': ['Möckernstr. 26', '10963 Berlin', 'Deutschland'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.49788644017145,
#        'lng': 13.379246459495729}],
#      'lat': 52.49788644017145,
#      'lng': 13.379246459495729,
#      'postalCode': '10963',
#      'state': 'Berlin'},
#     'name': 'Science Center Spektrum',
#     'referralId': 'v-1543578371'}]}}

# %%
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head(20)
# Out:
#                                            categories  hasPerk  \
# 0   [{'pluralName': 'History Museums', 'icon': {'s...    False
# 1   [{'pluralName': 'Art Museums', 'icon': {'suffi...    False
# 2   [{'pluralName': 'History Museums', 'icon': {'s...    False
# 3   [{'pluralName': 'Art Museums', 'icon': {'suffi...    False
# 4   [{'pluralName': 'Science Museums', 'icon': {'s...    False
# 5   [{'pluralName': 'History Museums', 'icon': {'s...    False
# 6   [{'pluralName': 'History Museums', 'icon': {'s...    False
# 7   [{'pluralName': 'History Museums', 'icon': {'s...    False
# 8   [{'pluralName': 'Tourist Information Centers',...    False
# 9   [{'pluralName': 'Art Museums', 'icon': {'suffi...    False
# 10  [{'pluralName': 'Science Museums', 'icon': {'s...    False
# 11  [{'pluralName': 'Palaces', 'icon': {'suffix': ...    False
# 12  [{'pluralName': 'History Museums', 'icon': {'s...    False
# 13  [{'pluralName': 'Art Museums', 'icon': {'suffi...    False
# 14  [{'pluralName': 'History Museums', 'icon': {'s...    False
# 15  [{'pluralName': 'Art Museums', 'icon': {'suffi...    False
# 16  [{'pluralName': 'History Museums', 'icon': {'s...    False
# 17  [{'pluralName': 'Art Museums', 'icon': {'suffi...    False
# 18  [{'pluralName': 'History Museums', 'icon': {'s...    False
# 19  [{'pluralName': 'Historic Sites', 'icon': {'su...    False
#
#                           id        location.address location.cc  \
# 0   4ae44d24f964a520eb9921e3       Am Kupfergraben 5          DE
# 1   4adcda81f964a5205d4821e3       Am Kupfergraben 5          DE
# 2   4adcda83f964a520b24821e3            Bodestr. 1-3          DE
# 3   4adcda7cf964a520594721e3            Bodestr. 1-3          DE
# 4   4adcda81f964a520594821e3        Invalidenstr. 43          DE
# 5   4adcda83f964a520aa4821e3      Unter den Linden 2          DE
# 6   4b39de5bf964a520585f25e3         Brunnenstr. 105          DE
# 7   53245d85498ebfbd8bccba47       Bernauer Str. 111          DE
# 8   4e8f16ebf5b910ae60bb90dc       Bernauer Str. 119          DE
# 9   4adcda81f964a520784821e3  Alte Jakobstr. 124-128          DE
# 10  4b659b4bf964a52032f62ae3        Trebbiner Str. 9          DE
# 11  4adcda7cf964a520564721e3       Spandauer Damm 20          DE
# 12  4ae9c897f964a52062b621e3  Karl-Liebknecht-Str. 1          DE
# 13  4adcda83f964a520b04821e3    Niederkirchnerstr. 7          DE
# 14  4adcda81f964a520574821e3         Am Lustgarten 1          DE
# 15  4adcda83f964a520ab4821e3     Invalidenstr. 50-51          DE
# 16  4adcda83f964a520944821e3    Niederkirchnerstr. 8          DE
# 17  5228b7737e484ee899dce79b    Hardenbergstr. 22-24          DE
# 18  4adcda81f964a520484821e3          Ruschestr. 103          DE
# 19  4bd975242e6f0f4708960a08       Bernauer Str. 111          DE
#
#    location.city location.country location.crossStreet  location.distance  \
# 0         Berlin      Deutschland                  NaN                 79
# 1         Berlin      Deutschland                  NaN                 58
# 2         Berlin      Deutschland         Museumsinsel                 71
# 3         Berlin      Deutschland                  NaN                 75
# 4         Berlin      Deutschland                  NaN               1627
# 5         Berlin      Deutschland                  NaN                335
# 6         Berlin      Deutschland                  NaN               3059
# 7         Berlin      Deutschland            Ackerstr.               1711
# 8         Berlin      Deutschland           Gartenstr.               1598
# 9         Berlin      Deutschland                  NaN               1924
# 10        Berlin      Deutschland                  NaN               2852
# 11        Berlin      Deutschland                  NaN               6901
# 12        Berlin      Deutschland                  NaN                352
# 13        Berlin      Deutschland                  NaN               1865
# 14        Berlin      Deutschland                  NaN                161
# 15        Berlin      Deutschland                  NaN               1879
# 16        Berlin      Deutschland          Wilhelmstr.               1812
# 17        Berlin      Deutschland                  NaN               4784
# 18        Berlin      Deutschland               Haus 1               6122
# 19        Berlin      Deutschland            Ackerstr.               1649
#
#                             location.formattedAddress  \
# 0      [Am Kupfergraben 5, 10117 Berlin, Deutschland]
# 1      [Am Kupfergraben 5, 10117 Berlin, Deutschland]
# 2   [Bodestr. 1-3 (Museumsinsel), 10178 Berlin, De...
# 3           [Bodestr. 1-3, 10178 Berlin, Deutschland]
# 4       [Invalidenstr. 43, 10115 Berlin, Deutschland]
# 5     [Unter den Linden 2, 10117 Berlin, Deutschland]
# 6        [Brunnenstr. 105, 13355 Berlin, Deutschland]
# 7   [Bernauer Str. 111 (Ackerstr.), 13355 Berlin, ...
# 8   [Bernauer Str. 119 (Gartenstr.), 13355 Berlin,...
# 9   [Alte Jakobstr. 124-128, 10969 Berlin, Deutsch...
# 10      [Trebbiner Str. 9, 10963 Berlin, Deutschland]
# 11     [Spandauer Damm 20, 14059 Berlin, Deutschland]
# 12  [Karl-Liebknecht-Str. 1, 10178 Berlin, Deutsch...
# 13  [Niederkirchnerstr. 7, 10963 Berlin, Deutschland]
# 14       [Am Lustgarten 1, 10178 Berlin, Deutschland]
# 15   [Invalidenstr. 50-51, 10557 Berlin, Deutschland]
# 16  [Niederkirchnerstr. 8 (Wilhelmstr.), 10963 Ber...
# 17  [Hardenbergstr. 22-24, 10623 Berlin, Deutschland]
# 18  [Ruschestr. 103 (Haus 1), 10365 Berlin, Deutsc...
# 19  [Bernauer Str. 111 (Ackerstr.), 13355 Berlin, ...
#
#                               location.labeledLatLngs  location.lat  \
# 0   [{'label': 'display', 'lat': 52.520843, 'lng':...     52.520843
# 1   [{'label': 'display', 'lat': 52.52070890284828...     52.520709
# 2   [{'label': 'display', 'lat': 52.5201576091737,...     52.520158
# 3   [{'label': 'display', 'lat': 52.520796016677, ...     52.520796
# 4   [{'label': 'display', 'lat': 52.53027102772721...     52.530271
# 5   [{'label': 'display', 'lat': 52.5177881130353,...     52.517788
# 6   [{'label': 'display', 'lat': 52.54774454143173...     52.547745
# 7   [{'label': 'display', 'lat': 52.53538550851109...     52.535386
# 8   [{'label': 'display', 'lat': 52.53376701989025...     52.533767
# 9   [{'label': 'display', 'lat': 52.50349443401274...     52.503494
# 10  [{'label': 'display', 'lat': 52.49845963432423...     52.498460
# 11  [{'label': 'display', 'lat': 52.52089530162469...     52.520895
# 12  [{'label': 'display', 'lat': 52.51940384308041...     52.519404
# 13  [{'label': 'display', 'lat': 52.50699630378523...     52.506996
# 14  [{'label': 'display', 'lat': 52.51953741567019...     52.519537
# 15  [{'label': 'display', 'lat': 52.52811924345585...     52.528119
# 16  [{'label': 'display', 'lat': 52.50688355705029...     52.506884
# 17  [{'label': 'display', 'lat': 52.50678358537336...     52.506784
# 18  [{'label': 'display', 'lat': 52.514366619602, ...     52.514367
# 19  [{'label': 'display', 'lat': 52.53489605251921...     52.534896
#
#     location.lng location.neighborhood location.postalCode location.state  \
# 0      13.396395          Museumsinsel               10117         Berlin
# 1      13.396697                   NaN               10117         Berlin
# 2      13.397838          Museumsinsel               10178         Berlin
# 3      13.398673          Museumsinsel               10178         Berlin
# 4      13.379281                   NaN               10115         Berlin
# 5      13.396948                   NaN               10117         Berlin
# 6      13.388864                   NaN               13355         Berlin
# 7      13.389668                   NaN               13355         Berlin
# 8      13.387485         Gesundbrunnen               13355         Berlin
# 9      13.398403                   NaN               10969         Berlin
# 10     13.376881                   NaN               10963         Berlin
# 11     13.295667        Charlottenburg               14059         Berlin
# 12     13.402239                   NaN               10178         Berlin
# 13     13.381886             Kreuzberg               10963         Berlin
# 14     13.398803          Museumsinsel               10178         Berlin
# 15     13.372576          Hauptbahnhof               10557         Berlin
# 16     13.383601                   NaN               10963         Berlin
# 17     13.330789                   NaN               10623         Berlin
# 18     13.487327                   NaN               10365         Berlin
# 19     13.390140                 Mitte               13355         Berlin
#
#                                                  name    referralId  \
# 0                                      Pergamonmuseum  v-1543578371
# 1                         Museum für Islamische Kunst  v-1543578371
# 2                                        Neues Museum  v-1543578371
# 3                                Alte Nationalgalerie  v-1543578371
# 4                               Museum für Naturkunde  v-1543578371
# 5                       Deutsches Historisches Museum  v-1543578371
# 6                           Berliner Unterwelten e.V.  v-1543578371
# 7   Dokumentationszentrum | Documentation Center (...  v-1543578371
# 8   Besucherzentrum | Visitor Center (Besucherzent...  v-1543578371
# 9                                 Berlinische Galerie  v-1543578371
# 10  Deutsches Technikmuseum (Deutsches Technikmuse...  v-1543578371
# 11                             Schloss Charlottenburg  v-1543578371
# 12                                         DDR Museum  v-1543578371
# 13                                 Martin-Gropius-Bau  v-1543578371
# 14                                       Altes Museum  v-1543578371
# 15           Hamburger Bahnhof – Museum für Gegenwart  v-1543578371
# 16                            Topographie des Terrors  v-1543578371
# 17                                         C/O Berlin  v-1543578371
# 18                                       Stasi-Museum  v-1543578371
# 19                        Gedenkstätte Berliner Mauer  v-1543578371
#
#    venuePage.id
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12     48098990
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17    124350650
# 18          NaN
# 19          NaN

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                                      Pergamonmuseum
# 1                         Museum für Islamische Kunst
# 2                                        Neues Museum
# 3                                Alte Nationalgalerie
# 4                               Museum für Naturkunde
# 5                       Deutsches Historisches Museum
# 6                           Berliner Unterwelten e.V.
# 7   Dokumentationszentrum | Documentation Center (...
# 8   Besucherzentrum | Visitor Center (Besucherzent...
# 9                                 Berlinische Galerie
# 10  Deutsches Technikmuseum (Deutsches Technikmuse...
# 11                             Schloss Charlottenburg
# 12                                         DDR Museum
# 13                                 Martin-Gropius-Bau
# 14                                       Altes Museum
# 15           Hamburger Bahnhof – Museum für Gegenwart
# 16                            Topographie des Terrors
# 17                                         C/O Berlin
# 18                                       Stasi-Museum
# 19                        Gedenkstätte Berliner Mauer
# 20         Jüdisches Museum (Jüdisches Museum Berlin)
# 21                                     Gemäldegalerie
# 22                           Deutsches Spionagemuseum
# 23                              Zeiss-Großplanetarium
# 24                                    Madame Tussauds
# 25                              Classic Remise Berlin
# 26                              Museum für Fotografie
# 27                               Computerspielemuseum
# 28                                       Tränenpalast
# 29                            Science Center Spektrum
#
#                     categories                 address  cc    city  \
# 0               History Museum       Am Kupfergraben 5  DE  Berlin
# 1                   Art Museum       Am Kupfergraben 5  DE  Berlin
# 2               History Museum            Bodestr. 1-3  DE  Berlin
# 3                   Art Museum            Bodestr. 1-3  DE  Berlin
# 4               Science Museum        Invalidenstr. 43  DE  Berlin
# 5               History Museum      Unter den Linden 2  DE  Berlin
# 6               History Museum         Brunnenstr. 105  DE  Berlin
# 7               History Museum       Bernauer Str. 111  DE  Berlin
# 8   Tourist Information Center       Bernauer Str. 119  DE  Berlin
# 9                   Art Museum  Alte Jakobstr. 124-128  DE  Berlin
# 10              Science Museum        Trebbiner Str. 9  DE  Berlin
# 11                      Palace       Spandauer Damm 20  DE  Berlin
# 12              History Museum  Karl-Liebknecht-Str. 1  DE  Berlin
# 13                  Art Museum    Niederkirchnerstr. 7  DE  Berlin
# 14              History Museum         Am Lustgarten 1  DE  Berlin
# 15                  Art Museum     Invalidenstr. 50-51  DE  Berlin
# 16              History Museum    Niederkirchnerstr. 8  DE  Berlin
# 17                  Art Museum    Hardenbergstr. 22-24  DE  Berlin
# 18              History Museum          Ruschestr. 103  DE  Berlin
# 19               Historic Site       Bernauer Str. 111  DE  Berlin
# 20              History Museum         Lindenstr. 9-14  DE  Berlin
# 21                  Art Museum     Matthäikirchplatz 8  DE  Berlin
# 22              History Museum       Leipziger Platz 9  DE  Berlin
# 23                 Planetarium     Prenzlauer Allee 80  DE  Berlin
# 24                      Museum     Unter den Linden 74  DE  Berlin
# 25                      Museum            Wiebestr. 36  DE  Berlin
# 26                  Art Museum            Jebensstr. 2  DE  Berlin
# 27              Science Museum     Karl-Marx-Allee 93a  DE  Berlin
# 28               Historic Site        Reichstagufer 17  DE  Berlin
# 29              Science Museum          Möckernstr. 26  DE  Berlin
#
#         country       crossStreet  distance  \
# 0   Deutschland               NaN        79
# 1   Deutschland               NaN        58
# 2   Deutschland      Museumsinsel        71
# 3   Deutschland               NaN        75
# 4   Deutschland               NaN      1627
# 5   Deutschland               NaN       335
# 6   Deutschland               NaN      3059
# 7   Deutschland         Ackerstr.      1711
# 8   Deutschland        Gartenstr.      1598
# 9   Deutschland               NaN      1924
# 10  Deutschland               NaN      2852
# 11  Deutschland               NaN      6901
# 12  Deutschland               NaN       352
# 13  Deutschland               NaN      1865
# 14  Deutschland               NaN       161
# 15  Deutschland               NaN      1879
# 16  Deutschland       Wilhelmstr.      1812
# 17  Deutschland               NaN      4784
# 18  Deutschland            Haus 1      6122
# 19  Deutschland         Ackerstr.      1649
# 20  Deutschland  Am Berlin Museum      2102
# 21  Deutschland               NaN      2478
# 22  Deutschland               NaN      1831
# 23  Deutschland               NaN      3215
# 24  Deutschland       Wilhelmstr.      1181
# 25  Deutschland     Sickingenstr.      5442
# 26  Deutschland               NaN      4639
# 27  Deutschland               NaN      3025
# 28  Deutschland               NaN       704
# 29  Deutschland               NaN      2834
#
#                                      formattedAddress  \
# 0      [Am Kupfergraben 5, 10117 Berlin, Deutschland]
# 1      [Am Kupfergraben 5, 10117 Berlin, Deutschland]
# 2   [Bodestr. 1-3 (Museumsinsel), 10178 Berlin, De...
# 3           [Bodestr. 1-3, 10178 Berlin, Deutschland]
# 4       [Invalidenstr. 43, 10115 Berlin, Deutschland]
# 5     [Unter den Linden 2, 10117 Berlin, Deutschland]
# 6        [Brunnenstr. 105, 13355 Berlin, Deutschland]
# 7   [Bernauer Str. 111 (Ackerstr.), 13355 Berlin, ...
# 8   [Bernauer Str. 119 (Gartenstr.), 13355 Berlin,...
# 9   [Alte Jakobstr. 124-128, 10969 Berlin, Deutsch...
# 10      [Trebbiner Str. 9, 10963 Berlin, Deutschland]
# 11     [Spandauer Damm 20, 14059 Berlin, Deutschland]
# 12  [Karl-Liebknecht-Str. 1, 10178 Berlin, Deutsch...
# 13  [Niederkirchnerstr. 7, 10963 Berlin, Deutschland]
# 14       [Am Lustgarten 1, 10178 Berlin, Deutschland]
# 15   [Invalidenstr. 50-51, 10557 Berlin, Deutschland]
# 16  [Niederkirchnerstr. 8 (Wilhelmstr.), 10963 Ber...
# 17  [Hardenbergstr. 22-24, 10623 Berlin, Deutschland]
# 18  [Ruschestr. 103 (Haus 1), 10365 Berlin, Deutsc...
# 19  [Bernauer Str. 111 (Ackerstr.), 13355 Berlin, ...
# 20  [Lindenstr. 9-14 (Am Berlin Museum), 10969 Ber...
# 21   [Matthäikirchplatz 8, 10785 Berlin, Deutschland]
# 22     [Leipziger Platz 9, 10117 Berlin, Deutschland]
# 23   [Prenzlauer Allee 80, 10405 Berlin, Deutschland]
# 24  [Unter den Linden 74 (Wilhelmstr.), 10117 Berl...
# 25  [Wiebestr. 36 (Sickingenstr.), 10553 Berlin, D...
# 26          [Jebensstr. 2, 10623 Berlin, Deutschland]
# 27   [Karl-Marx-Allee 93a, 10243 Berlin, Deutschland]
# 28      [Reichstagufer 17, 10117 Berlin, Deutschland]
# 29        [Möckernstr. 26, 10963 Berlin, Deutschland]
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 52.520843, 'lng':...  52.520843  13.396395
# 1   [{'label': 'display', 'lat': 52.52070890284828...  52.520709  13.396697
# 2   [{'label': 'display', 'lat': 52.5201576091737,...  52.520158  13.397838
# 3   [{'label': 'display', 'lat': 52.520796016677, ...  52.520796  13.398673
# 4   [{'label': 'display', 'lat': 52.53027102772721...  52.530271  13.379281
# 5   [{'label': 'display', 'lat': 52.5177881130353,...  52.517788  13.396948
# 6   [{'label': 'display', 'lat': 52.54774454143173...  52.547745  13.388864
# 7   [{'label': 'display', 'lat': 52.53538550851109...  52.535386  13.389668
# 8   [{'label': 'display', 'lat': 52.53376701989025...  52.533767  13.387485
# 9   [{'label': 'display', 'lat': 52.50349443401274...  52.503494  13.398403
# 10  [{'label': 'display', 'lat': 52.49845963432423...  52.498460  13.376881
# 11  [{'label': 'display', 'lat': 52.52089530162469...  52.520895  13.295667
# 12  [{'label': 'display', 'lat': 52.51940384308041...  52.519404  13.402239
# 13  [{'label': 'display', 'lat': 52.50699630378523...  52.506996  13.381886
# 14  [{'label': 'display', 'lat': 52.51953741567019...  52.519537  13.398803
# 15  [{'label': 'display', 'lat': 52.52811924345585...  52.528119  13.372576
# 16  [{'label': 'display', 'lat': 52.50688355705029...  52.506884  13.383601
# 17  [{'label': 'display', 'lat': 52.50678358537336...  52.506784  13.330789
# 18  [{'label': 'display', 'lat': 52.514366619602, ...  52.514367  13.487327
# 19  [{'label': 'display', 'lat': 52.53489605251921...  52.534896  13.390140
# 20  [{'label': 'display', 'lat': 52.50194638892942...  52.501946  13.395241
# 21  [{'label': 'display', 'lat': 52.50896347323177...  52.508963  13.366553
# 22  [{'label': 'display', 'lat': 52.50889483693721...  52.508895  13.378859
# 23  [{'label': 'display', 'lat': 52.5431275302158,...  52.543128  13.427647
# 24  [{'label': 'display', 'lat': 52.51676928739977...  52.516769  13.381401
# 25  [{'label': 'display', 'lat': 52.53026879229302...  52.530269  13.318734
# 26  [{'label': 'display', 'lat': 52.50803664535491...  52.508037  13.332352
# 27  [{'label': 'display', 'lat': 52.51748970846354...  52.517490  13.441900
# 28  [{'label': 'display', 'lat': 52.52085424559891...  52.520854  13.387162
# 29  [{'label': 'display', 'lat': 52.49788644017145...  52.497886  13.379246
#
#       neighborhood postalCode   state                        id
# 0     Museumsinsel      10117  Berlin  4ae44d24f964a520eb9921e3
# 1              NaN      10117  Berlin  4adcda81f964a5205d4821e3
# 2     Museumsinsel      10178  Berlin  4adcda83f964a520b24821e3
# 3     Museumsinsel      10178  Berlin  4adcda7cf964a520594721e3
# 4              NaN      10115  Berlin  4adcda81f964a520594821e3
# 5              NaN      10117  Berlin  4adcda83f964a520aa4821e3
# 6              NaN      13355  Berlin  4b39de5bf964a520585f25e3
# 7              NaN      13355  Berlin  53245d85498ebfbd8bccba47
# 8    Gesundbrunnen      13355  Berlin  4e8f16ebf5b910ae60bb90dc
# 9              NaN      10969  Berlin  4adcda81f964a520784821e3
# 10             NaN      10963  Berlin  4b659b4bf964a52032f62ae3
# 11  Charlottenburg      14059  Berlin  4adcda7cf964a520564721e3
# 12             NaN      10178  Berlin  4ae9c897f964a52062b621e3
# 13       Kreuzberg      10963  Berlin  4adcda83f964a520b04821e3
# 14    Museumsinsel      10178  Berlin  4adcda81f964a520574821e3
# 15    Hauptbahnhof      10557  Berlin  4adcda83f964a520ab4821e3
# 16             NaN      10963  Berlin  4adcda83f964a520944821e3
# 17             NaN      10623  Berlin  5228b7737e484ee899dce79b
# 18             NaN      10365  Berlin  4adcda81f964a520484821e3
# 19           Mitte      13355  Berlin  4bd975242e6f0f4708960a08
# 20             NaN      10969  Berlin  4adcda81f964a520584821e3
# 21             NaN      10785  Berlin  4adcda83f964a520934821e3
# 22             NaN      10117  Berlin  55fa78a1498ea1907ff6be9f
# 23             NaN      10405  Berlin  4adcda7df964a520914721e3
# 24             NaN      10117  Berlin  4b88e416f964a5203d1232e3
# 25             NaN      10553  Berlin  4adcda83f964a520af4821e3
# 26             NaN      10623  Berlin  4adcda83f964a520b44821e3
# 27             NaN      10243  Berlin  4c2d9e87260bc92801531ad3
# 28             NaN      10117  Berlin  4cc9350ed147a09328aee5ae
# 29             NaN      10963  Berlin  4b991062f964a520f35e35e3

# %%
venues_map = folium.Map(location=[lat,long], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [lat, long],
    radius=10,
    color='red',
    popup='Venues',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)


for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4adcda80f964a5201c4821e3' # ID of Museumsinsel
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4adcda80f964a5201c4821e3?client_id=G0XJ2XFI1IPZMUR52JRVDEA31QO4DTXKTTIQ1DMOGM5EN0PU&client_secret=ZPA4XLVKKH5APZSWDPD2SEW3FZ02GNMFTXY1KJG4KBNHRYAB&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['hereNow', 'venueRatingBlacklisted', 'canonicalUrl', 'ok', 'listed', 'tips', 'shortUrl', 'attributes', 'name', 'id', 'contact', 'bestPhoto', 'location', 'colors', 'photos', 'rating', 'ratingColor', 'url', 'reasons', 'ratingSignals', 'verified', 'specials', 'beenHere', 'description', 'createdAt', 'dislike', 'timeZone', 'inbox', 'pageUpdates', 'categories', 'stats', 'likes'])
# {'attributes': {'groups': []},
#  'beenHere': {'count': 0,
#   'lastCheckinExpiredAt': 0,
#   'marked': False,
#   'unconfirmedCount': 0},
#  'bestPhoto': {'createdAt': 1374171324,
#   'height': 612,
#   'id': '51e830bc498ec2f868c4b311',
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#   'suffix': '/87513_j_QCdlMHWkHpsdHr7a10yAbWQgxOjg5a-ZimGBTr438.jpg',
#   'visibility': 'public',
#   'width': 612},
#  'canonicalUrl': 'https://foursquare.com/v/museumsinsel/4adcda80f964a5201c4821e3',
#  'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#     'suffix': '.png'},
#    'id': '50aaa4314b90af0d42d5de10',
#    'name': 'Island',
#    'pluralName': 'Islands',
#    'primary': True,
#    'shortName': 'Island'},
#   {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#     'suffix': '.png'},
#    'id': '4bf58dd8d48988d12d941735',
#    'name': 'Monument / Landmark',
#    'pluralName': 'Monuments / Landmarks',
#    'shortName': 'Landmark'}],
#  'colors': {'algoVersion': 3,
#   'highlightColor': {'photoId': '51e830bc498ec2f868c4b311', 'value': -6252416},
#   'highlightTextColor': {'photoId': '51e830bc498ec2f868c4b311',
#    'value': -16777216}},
#  'contact': {},
#  'createdAt': 1255987840,
#  'description': 'Die Museumsinsel ist die nördliche Spitze der Spreeinsel in der historischen Mitte von Berlin. Sie ist die Keimzelle der Berliner Museumslandschaft und mit ihren Museen heute ein vielbesuchter touristischer Anlaufpunkt und einer der wichtigsten Museumskomplexe der Welt.',
#  'dislike': False,
#  'hereNow': {'count': 0, 'groups': [], 'summary': 'Nobody here'},
#  'id': '4adcda80f964a5201c4821e3',
#  'inbox': {'count': 0, 'items': []},
#  'likes': {'count': 798,
#   'groups': [{'count': 798, 'items': [], 'type': 'others'}],
#   'summary': '798 Likes'},
#  'listed': {'count': 896,
#   'groups': [{'count': 896,
#     'items': [{'canonicalUrl': 'https://foursquare.com/p/wanna-see-it-all/13090265/list/best-of-world-edition-part-3',
#       'collaborative': False,
#       'createdAt': 1319129853,
#       'description': 'We will create a series of list marking the best places to eat sleep and visit outside the United States. We will 10 or more places a day. We will find the best tips and remarks about each place.',
#       'editable': False,
#       'followers': {'count': 170},
#       'id': '4ea052fdb80362c662b027c7',
#       'listItems': {'count': 200,
#        'items': [{'createdAt': 1319393921,
#          'id': 't4e771552cc3fc1186ee6d042',
#          'photo': {'createdAt': 1318687752,
#           'height': 612,
#           'id': '4e9994084690ec5f628e22e1',
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/0CRAJGCSCGGDHFOLNJ2C0BFZSKU0UYHLU1KGVTNC3E42MPUF.jpg',
#           'user': {'firstName': 'Marc',
#            'gender': 'male',
#            'id': '1799767',
#            'lastName': 'Feldmann',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/EYHFMCC1HVPVG301.jpg'}},
#           'visibility': 'public',
#           'width': 612}}]},
#       'logView': True,
#       'name': 'Best of World Edition part 3',
#       'photo': {'createdAt': 1318038426,
#        'height': 540,
#        'id': '4e8fab9a9adf26eeb9b5c491',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/L2T232TVQ4WMAI5PS0EWHZJKDGKRZJNC3KFVMAFW5RNQIFIQ.jpg',
#        'user': {'firstName': 'Dallas Nagata',
#         'gender': 'female',
#         'id': '332701',
#         'lastName': 'White',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/ZDVOINH0AO5FO2Q3.jpg'}},
#        'visibility': 'public',
#        'width': 720},
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1469966161,
#       'url': '/p/wanna-see-it-all/13090265/list/best-of-world-edition-part-3',
#       'user': {'firstName': 'Wanna See It All',
#        'gender': 'none',
#        'id': '13090265',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/3O0WUCXPPTGM1WMO.png'},
#        'type': 'page'}},
#      {'canonicalUrl': 'https://foursquare.com/bestwesternce/list/berlin--germany',
#       'collaborative': False,
#       'createdAt': 1313582823,
#       'description': 'Visit cosmopolitan Berlin! A few days is not enough to see everything Berlin has to offer. German history, modern architecture, first class museums, stylish clubs and international foods!',
#       'editable': False,
#       'followers': {'count': 354},
#       'id': '4e4baee7fa7671a85cec56f8',
#       'listItems': {'count': 47,
#        'items': [{'createdAt': 1313582823,
#          'id': 't4e204798922e11c006640fff',
#          'photo': {'createdAt': 1310738328,
#           'height': 480,
#           'id': '4e204798922e11c006641001',
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/XCCBHPLP0511L1IMWB3NSQBOOWCLQSODXR2SKTEZCQ3F0YTO.jpg',
#           'user': {'firstName': 'Best Western Central Europe',
#            'gender': 'none',
#            'id': '9407435',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/9407435-TNBWV23T4AF30XMX.png'},
#            'type': 'chain'},
#           'visibility': 'public',
#           'width': 720}}]},
#       'logView': True,
#       'name': 'Berlin / Germany',
#       'photo': {'createdAt': 1310736145,
#        'height': 480,
#        'id': '4e203f11922e11c006640c52',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/NT1N3SOJ4KY0XN3OP0EFWUHF5LXHLK15HLY3FFT5BS4K353N.jpg',
#        'user': {'firstName': 'Best Western Central Europe',
#         'gender': 'none',
#         'id': '9407435',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/9407435-TNBWV23T4AF30XMX.png'},
#         'type': 'chain'},
#        'visibility': 'public',
#        'width': 720},
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1451916412,
#       'url': '/bestwesternce/list/berlin--germany',
#       'user': {'firstName': 'Best Western Central Europe',
#        'gender': 'none',
#        'id': '9407435',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/9407435-TNBWV23T4AF30XMX.png'},
#        'type': 'chain'}},
#      {'canonicalUrl': 'https://foursquare.com/rockchart/list/berlin-and-more',
#       'collaborative': False,
#       'createdAt': 1315937054,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 785},
#       'id': '4e6f9b1ed4c06eaf9c4266ca',
#       'listItems': {'count': 197,
#        'items': [{'createdAt': 1322673620,
#          'id': 't4ed28cfe490168f8d26391c2',
#          'photo': {'createdAt': 1321779699,
#           'height': 540,
#           'id': '4ec8c1f399115348da88f9f2',
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/WV2HYPR15GA31VTBWW2NHVGAIHYVW305YK3X43JZFKB0Z02F.jpg',
#           'user': {'firstName': 'Martin',
#            'gender': 'male',
#            'id': '1137659',
#            'lastName': 'Grothe',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/BYTQBLO3PWRF3UQG.jpg'}},
#           'visibility': 'public',
#           'width': 720}}]},
#       'name': 'Berlin And More',
#       'photo': {'createdAt': 1313772364,
#        'height': 431,
#        'id': '4e4e934c18383eb2af148c97',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/UD0G4JVOSWLXHQWRTUWKAEFUG2OZE1VCPLMO3LC1N5VAHAMS.jpg',
#        'user': {'firstName': 'Thilo',
#         'gender': 'male',
#         'id': '4907991',
#         'lastName': 'Wetzel',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/PO2THX0AZPDNMMT4.jpg'}},
#        'visibility': 'public',
#        'width': 720},
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1535605968,
#       'url': '/rockchart/list/berlin-and-more',
#       'user': {'firstName': 'Kent',
#        'gender': 'male',
#        'id': '7011247',
#        'lastName': 'Rudd',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/1QOTLFMYOQEO2Q4W.jpg'}}},
#      {'canonicalUrl': 'https://foursquare.com/mattedwards1987/list/unesco-world-heritage-sites-of-europe-part-1',
#       'collaborative': False,
#       'createdAt': 1346955328,
#       'description': 'This list is the most complete collection of the UNESCO World Heritage Sites of Europe (mainly Northern and Western Europe at the moment).',
#       'editable': False,
#       'followers': {'count': 208},
#       'id': '5048e840e4b0d14d965297ff',
#       'listItems': {'count': 197,
#        'items': [{'createdAt': 1347269403,
#          'id': 't4e771552cc3fc1186ee6d042',
#          'photo': {'createdAt': 1346342637,
#           'height': 537,
#           'id': '503f8eede4b0c05c11522b4d',
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/J7nHXZhvkmLEaY4nkMOGAYcrCUUvRnnYNCGsORmp7gI.jpg',
#           'user': {'firstName': 'Maks',
#            'gender': 'male',
#            'id': '20804411',
#            'lastName': 'Koss',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/YLAQKCIYYBFNDETY.jpg'}},
#           'visibility': 'public',
#           'width': 720}}]},
#       'name': 'UNESCO World Heritage Sites of Europe (Part 1)',
#       'photo': {'createdAt': 1339243917,
#        'height': 612,
#        'id': '4fd33d8de4b0d45a9531d136',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/YlfhDWAfK43F0IDpUSv3QVEZkRflT9WdBFRhXJud9D8.jpg',
#        'user': {'firstName': 'Ryan',
#         'gender': 'male',
#         'id': '225811',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/5JAGWQ3HHSYNO1JI.jpg'}},
#        'visibility': 'public',
#        'width': 612},
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1518946231,
#       'url': '/mattedwards1987/list/unesco-world-heritage-sites-of-europe-part-1',
#       'user': {'firstName': 'Matt',
#        'gender': 'male',
#        'id': '1341944',
#        'lastName': 'E',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/1341944_JxFrX13i_CsYwroSkuWi4D8-g99m0VZaiz2ztNJfnesr-cd0X1mw7BCR3qDaDij9gOgtPMYb6'}}}],
#     'name': 'Lists from other people',
#     'type': 'others'}]},
#  'location': {'address': 'Am Lustgarten',
#   'cc': 'DE',
#   'city': 'Berlin',
#   'country': 'Deutschland',
#   'crossStreet': 'Bodestr.',
#   'formattedAddress': ['Am Lustgarten (Bodestr.)',
#    '10178 Berlin',
#    'Deutschland'],
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 52.52029572914336,
#     'lng': 13.398785634143882}],
#   'lat': 52.52029572914336,
#   'lng': 13.398785634143882,
#   'neighborhood': 'Museumsinsel',
#   'postalCode': '10178',
#   'state': 'Berlin'},
#  'name': 'Museumsinsel',
#  'ok': False,
#  'pageUpdates': {'count': 0, 'items': []},
#  'photos': {'count': 1354,
#   'groups': [{'count': 0,
#     'items': [],
#     'name': "Friends' check-in photos",
#     'type': 'checkin'},
#    {'count': 1354,
#     'items': [{'createdAt': 1374171324,
#       'height': 612,
#       'id': '51e830bc498ec2f868c4b311',
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#       'suffix': '/87513_j_QCdlMHWkHpsdHr7a10yAbWQgxOjg5a-ZimGBTr438.jpg',
#       'user': {'firstName': 'Matas',
#        'gender': 'male',
#        'id': '87513',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/87513_fedN96Lm_0y0mPMGHRP2q1SuHWPDXNC9bWOBOdk0LQQPYC3m4mHrMfih-ujZTCzxGzMJ-q46u.jpg'}},
#       'visibility': 'public',
#       'width': 612}],
#     'name': 'Venue photos',
#     'type': 'venue'}],
#   'summary': '0 photos'},
#  'rating': 9.4,
#  'ratingColor': '00B551',
#  'ratingSignals': 913,
#  'reasons': {'count': 1,
#   'items': [{'reasonName': 'rawLikesReason',
#     'summary': 'Lots of people like this place',
#     'type': 'general'}]},
#  'shortUrl': 'http://4sq.com/aNELFp',
#  'specials': {'count': 0, 'items': []},
#  'stats': {'tipCount': 101},
#  'timeZone': 'Europe/Berlin',
#  'tips': {'count': 101,
#   'groups': [{'count': 101,
#     'items': [{'agreeCount': 7,
#       'canonicalUrl': 'https://foursquare.com/item/5187a7a8498e8372f4b4b7ff',
#       'createdAt': 1367844776,
#       'disagreeCount': 0,
#       'id': '5187a7a8498e8372f4b4b7ff',
#       'lang': 'en',
#       'likes': {'count': 6,
#        'groups': [{'count': 6,
#          'items': [{'firstName': 'Jacqueline',
#            'gender': 'female',
#            'id': '47775706',
#            'lastName': 'Cousins',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/30N5VODCFZR1ZKKO.jpg'}},
#           {'firstName': 'Jana',
#            'gender': 'female',
#            'id': '17727938',
#            'lastName': 'von Oehsen',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/17727938_0B1-RfFe_Z_2QPvZgzwLljMmDDDJXR4cJgRPxNjp9sf3-uQOW-Lu5_tYlQTS-DWa91GsOxSEf.jpg'}},
#           {'firstName': 'Gordana',
#            'gender': 'female',
#            'id': '60676306',
#            'lastName': 'Marinković',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/CBGILWCLEPAWGDD2.jpg'}},
#           {'firstName': 'Dora',
#            'gender': 'female',
#            'id': '33142955',
#            'lastName': 'Ayala',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/33142955-KOXQSSGM3BPRNLMI.jpg'}}],
#          'type': 'others'}],
#        'summary': '6 likes'},
#       'logView': True,
#       'photo': {'createdAt': 1367844780,
#        'height': 530,
#        'id': '5187a7ac8bbd70ef754c08a7',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'},
#        'suffix': '/48647760_5frlje8_pnEHXNy6I9gPp-eTcfMkWceXy_jOa0cs-B4.jpg',
#        'visibility': 'public',
#        'width': 800},
#       'photourl': 'https://fastly.4sqi.net/img/general/original/48647760_5frlje8_pnEHXNy6I9gPp-eTcfMkWceXy_jOa0cs-B4.jpg',
#       'text': "5 museums on one island make Berlin's Museum Island a really cool spot to visit!",
#       'todo': {'count': 0},
#       'type': 'user',
#       'user': {'firstName': 'GowithOh',
#        'gender': 'none',
#        'id': '48647760',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/0KUE3N5UOK0U3B24.jpg'},
#        'type': 'chain'}}],
#     'name': 'All tips',
#     'type': 'others'}]},
#  'url': 'https://www.museumsinsel-berlin.de',
#  'venueRatingBlacklisted': True,
#  'verified': False}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 9.4

# %%
venue_id = '4e2db06ce4cd3bc166ac4a00' # ID of Taxistand Museumsinsel
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
result['response']['venue']['tips']['count']
# Out:
# 0

# %%
df=pd.DataFrame({'Name':dataframe_filtered['name']})

# %%
df['ID']=dataframe_filtered['id']
df
# Out:
#                                                  Name  \
# 0                                      Pergamonmuseum
# 1                         Museum für Islamische Kunst
# 2                                        Neues Museum
# 3                                Alte Nationalgalerie
# 4                               Museum für Naturkunde
# 5                       Deutsches Historisches Museum
# 6                           Berliner Unterwelten e.V.
# 7   Dokumentationszentrum | Documentation Center (...
# 8   Besucherzentrum | Visitor Center (Besucherzent...
# 9                                 Berlinische Galerie
# 10  Deutsches Technikmuseum (Deutsches Technikmuse...
# 11                             Schloss Charlottenburg
# 12                                         DDR Museum
# 13                                 Martin-Gropius-Bau
# 14                                       Altes Museum
# 15           Hamburger Bahnhof – Museum für Gegenwart
# 16                            Topographie des Terrors
# 17                                         C/O Berlin
# 18                                       Stasi-Museum
# 19                        Gedenkstätte Berliner Mauer
# 20         Jüdisches Museum (Jüdisches Museum Berlin)
# 21                                     Gemäldegalerie
# 22                           Deutsches Spionagemuseum
# 23                              Zeiss-Großplanetarium
# 24                                    Madame Tussauds
# 25                              Classic Remise Berlin
# 26                              Museum für Fotografie
# 27                               Computerspielemuseum
# 28                                       Tränenpalast
# 29                            Science Center Spektrum
#
#                           ID
# 0   4ae44d24f964a520eb9921e3
# 1   4adcda81f964a5205d4821e3
# 2   4adcda83f964a520b24821e3
# 3   4adcda7cf964a520594721e3
# 4   4adcda81f964a520594821e3
# 5   4adcda83f964a520aa4821e3
# 6   4b39de5bf964a520585f25e3
# 7   53245d85498ebfbd8bccba47
# 8   4e8f16ebf5b910ae60bb90dc
# 9   4adcda81f964a520784821e3
# 10  4b659b4bf964a52032f62ae3
# 11  4adcda7cf964a520564721e3
# 12  4ae9c897f964a52062b621e3
# 13  4adcda83f964a520b04821e3
# 14  4adcda81f964a520574821e3
# 15  4adcda83f964a520ab4821e3
# 16  4adcda83f964a520944821e3
# 17  5228b7737e484ee899dce79b
# 18  4adcda81f964a520484821e3
# 19  4bd975242e6f0f4708960a08
# 20  4adcda81f964a520584821e3
# 21  4adcda83f964a520934821e3
# 22  55fa78a1498ea1907ff6be9f
# 23  4adcda7df964a520914721e3
# 24  4b88e416f964a5203d1232e3
# 25  4adcda83f964a520af4821e3
# 26  4adcda83f964a520b44821e3
# 27  4c2d9e87260bc92801531ad3
# 28  4cc9350ed147a09328aee5ae
# 29  4b991062f964a520f35e35e3

# %%
id_list=df['ID']
type(id_list[0])
# Out:
# str

# %%
tips=[]
for i in id_list:
    venue_id=i
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    try:
        tips.append(result['response']['venue']['rating'])
    except:
        tips.append('NA')

# %%
df['Tips']=tips

# %%
df['lat']=dataframe_filtered['lat']
df['long']=dataframe_filtered['lng']
nodf=df
kclusters = 3
newdf=df.drop(['ID','Tips','Name'],axis=1)
newdf
kmeans = KMeans(n_clusters = kclusters, random_state = 0).fit(newdf)

# %%
LV_merged = newdf

from random import randint
randomArray = []
for i in range(0,5):
    randomArray.append(randint(0,2))
newLabels = np.append(kmeans.labels_, randomArray)
cluslabels=newLabels[5:]
LV_merged['Cluster Labels'] = cluslabels
LV_merged['Name']=nodf['Name']
LV_merged
# Out:
#           lat       long  Cluster Labels  \
# 0   52.520843  13.396395               1
# 1   52.520709  13.396697               1
# 2   52.520158  13.397838               1
# 3   52.520796  13.398673               1
# 4   52.530271  13.379281               1
# 5   52.517788  13.396948               1
# 6   52.547745  13.388864               2
# 7   52.535386  13.389668               1
# 8   52.533767  13.387485               1
# 9   52.503494  13.398403               1
# 10  52.498460  13.376881               1
# 11  52.520895  13.295667               1
# 12  52.519404  13.402239               2
# 13  52.506996  13.381886               0
# 14  52.519537  13.398803               1
# 15  52.528119  13.372576               1
# 16  52.506884  13.383601               1
# 17  52.506784  13.330789               1
# 18  52.514367  13.487327               0
# 19  52.534896  13.390140               1
# 20  52.501946  13.395241               2
# 21  52.508963  13.366553               2
# 22  52.508895  13.378859               0
# 23  52.543128  13.427647               1
# 24  52.516769  13.381401               1
# 25  52.530269  13.318734               0
# 26  52.508037  13.332352               0
# 27  52.517490  13.441900               0
# 28  52.520854  13.387162               1
# 29  52.497886  13.379246               0
#
#                                                  Name
# 0                                      Pergamonmuseum
# 1                         Museum für Islamische Kunst
# 2                                        Neues Museum
# 3                                Alte Nationalgalerie
# 4                               Museum für Naturkunde
# 5                       Deutsches Historisches Museum
# 6                           Berliner Unterwelten e.V.
# 7   Dokumentationszentrum | Documentation Center (...
# 8   Besucherzentrum | Visitor Center (Besucherzent...
# 9                                 Berlinische Galerie
# 10  Deutsches Technikmuseum (Deutsches Technikmuse...
# 11                             Schloss Charlottenburg
# 12                                         DDR Museum
# 13                                 Martin-Gropius-Bau
# 14                                       Altes Museum
# 15           Hamburger Bahnhof – Museum für Gegenwart
# 16                            Topographie des Terrors
# 17                                         C/O Berlin
# 18                                       Stasi-Museum
# 19                        Gedenkstätte Berliner Mauer
# 20         Jüdisches Museum (Jüdisches Museum Berlin)
# 21                                     Gemäldegalerie
# 22                           Deutsches Spionagemuseum
# 23                              Zeiss-Großplanetarium
# 24                                    Madame Tussauds
# 25                              Classic Remise Berlin
# 26                              Museum für Fotografie
# 27                               Computerspielemuseum
# 28                                       Tränenpalast
# 29                            Science Center Spektrum

# %%
LV_map_clusters = folium.Map(location = [lat,long], zoom_start = 13)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
markers_colors = []

for lat ,lng, poi, cluster in zip(LV_merged["lat"],LV_merged["long"],LV_merged['Name'],LV_merged['Cluster Labels']):
    label = folium.Popup(str(poi)+" Cluster "+str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat,lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7
    ).add_to(LV_map_clusters)

LV_map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
